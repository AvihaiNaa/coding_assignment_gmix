# %% [markdown]
# # Anesthesiologists allocation optimization

# %%
import utils

# %%
filename = './data/surgeries.csv'
surgeries = utils.read_surgeries_from_csv(filename)

# %%
scheduler = utils.SurgeryScheduler(num_rooms=20, rest_time=15)
scheduler.allocate_anesthesiologists(surgeries)

# %%
schedule = scheduler.get_schedule()
updates = scheduler.get_updates()

# %%
print("Final Schedule:")
print(schedule)
print("\nUpdates:")
print(updates)
# Out:
# Final Schedule:
#         room_id  anesthetist_id          start_time            end_time
# 0    0        0               0 2023-04-25 20:30:00 2023-04-25 21:00:00
# 1    1        1               1 2023-04-25 20:45:00 2023-04-25 21:00:00
# 2    2        2               2 2023-04-25 20:30:00 2023-04-25 21:00:00
# 3    3        3               3 2023-04-25 20:15:00 2023-04-25 20:45:00
# 4    4        4               4 2023-04-25 19:30:00 2023-04-25 20:45:00
# 5    5        5               5 2023-04-25 19:15:00 2023-04-25 21:00:00
# 6    6        6               6 2023-04-25 19:45:00 2023-04-25 20:45:00
# 7    7        7               7 2023-04-25 19:00:00 2023-04-25 20:30:00
# 8    9        8               8 2023-04-25 19:30:00 2023-04-25 21:00:00
# 9   10        9               9 2023-04-25 20:15:00 2023-04-25 20:45:00
# 10  11       10              10 2023-04-25 19:30:00 2023-04-25 21:00:00
# 11  22       11              11 2023-04-25 18:15:00 2023-04-25 19:00:00
# ...

# %% [markdown]
# ### Save to excel

# %%
updates.to_csv('updates.csv', index=True)
print("Updates saved to 'updates.xlsx'")
# Out:
# Updates saved to 'updates.xlsx'

# %%
utils.plot_day_schedule(updates)

# %% [markdown]
# ## Bonus

# %%
import bonus

# %%
filename = './data/surgeries.csv'
surgeries = bonus.read_surgeries_from_csv(filename)

# %%
bonus.solve_it_via_lp(surgeries)
# Out:
# C:\Users\aviha\AppData\Roaming\Python\Python39\site-packages\pulp\pulp.py:1352: UserWarning: Spaces are not permitted in the name. Converted to '_'
#   warnings.warn("Spaces are not permitted in the name. Converted to '_'")
# Status: Infeasible
# Anesthesiologist 1 is assigned to surgery 86
# Anesthesiologist 5 is assigned to surgery 25
# Anesthesiologist 6 is assigned to surgery 19
# Anesthesiologist 7 is assigned to surgery 86
# Anesthesiologist 9 is assigned to surgery 12
# Anesthesiologist 10 is assigned to surgery 91
# Anesthesiologist 13 is assigned to surgery 19
# Anesthesiologist 16 is assigned to surgery 38
# Anesthesiologist 17 is assigned to surgery 43
# Anesthesiologist 18 is assigned to surgery 85
# Anesthesiologist 19 is assigned to surgery 47
# Anesthesiologist 20 is assigned to surgery 12
# Anesthesiologist 21 is assigned to surgery 34
# Anesthesiologist 21 is assigned to surgery 70
# Anesthesiologist 21 is assigned to surgery 84
# ...
